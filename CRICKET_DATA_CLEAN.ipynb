# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\HP\Downloads\all_champions_trophy_matches_results.csv")
df2=pd.read_csv(r"C:\Users\HP\Downloads\archive (1)\all_champions_trophy_players_list.csv")

# %%
df1
# Out:
#             Team1         Team2                                  Toss  \
# 0    South Africa   West Indies  South Africa, elected to field first
# 1           India   West Indies           India, elected to bat first
# 2    South Africa     Sri Lanka     Sri Lanka, elected to field first
# 3        Pakistan   West Indies     West Indies, elected to bat first
# 4       Australia         India     Australia, elected to field first
# ..            ...           ...                                   ...
# 123         India      Pakistan      Pakistan, elected to field first
# 124     Australia       England     Australia, elected to field first
# 125   Afghanistan  South Africa    South Africa, elected to bat first
# 126    Bangladesh         India      Bangladesh, elected to bat first
# 127      Pakistan   New Zealand      Pakistan, elected to field first
#
#     Match days        Winner Player of the Match     Margin        Ground  \
# ...

# %%
df2
# Out:
#              Team  Year           Player Name
# 0     Afghanistan  2025  Hashmatullah Shahidi
# 1     Afghanistan  2025        Ibrahim Zadran
# 2     Afghanistan  2025         Ikram Alikhil
# 3     Afghanistan  2025    Rahmanullah Gurbaz
# 4     Afghanistan  2025       Sediqullah Atal
# ...           ...   ...                   ...
# 1150     Zimbabwe  2006            Piet Rinke
# 1151     Zimbabwe  2006        Prosper Utseya
# 1152     Zimbabwe  2006       Anthony Ireland
# 1153     Zimbabwe  2006          Ed Rainsford
# 1154     Zimbabwe  2006    Tafadzwa Kamungozi
#
# [1155 rows x 3 columns]

# %%
duplicate_count=df1.duplicated().sum()

# %%
duplicate_count
# Out:
# np.int64(0)

# %%
duplicate_count=df2.duplicated().sum()

# %%
duplicate_count
# Out:
# np.int64(0)

# %%
df1.isnull().sum()
# Out:
# Team1                           0
# Team2                           0
# Toss                            0
# Match days                      0
# Winner                          0
# Player of the Match             7
# Margin                          0
# Ground                          0
# Match Date                      0
# ODI Int Match                   0
# Team1 Avg Batting Ranking       0
# Team2 Avg Batting Ranking       0
# Team1 Avg Bowling Ranking       0
# Team2 Avg Bowling Ranking       0
# Team1 Total CTs participated    0
# Team1 Total CTs won             0
# Team2 Total CTs participated    0
# Team2 Total CTs won             0
# Team1 W/L ratio over Team2      0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Team           0
# Year           0
# Player Name    0
# dtype: int64

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# Team1                           0.00000
# Team2                           0.00000
# Toss                            0.00000
# Match days                      0.00000
# Winner                          0.00000
# Player of the Match             5.46875
# Margin                          0.00000
# Ground                          0.00000
# Match Date                      0.00000
# ODI Int Match                   0.00000
# Team1 Avg Batting Ranking       0.00000
# Team2 Avg Batting Ranking       0.00000
# Team1 Avg Bowling Ranking       0.00000
# Team2 Avg Bowling Ranking       0.00000
# Team1 Total CTs participated    0.00000
# Team1 Total CTs won             0.00000
# Team2 Total CTs participated    0.00000
# Team2 Total CTs won             0.00000
# Team1 W/L ratio over Team2      0.00000
# dtype: float64

# %%
df2.isnull().sum()/len(df2)*100
# Out:
# Team           0.0
# Year           0.0
# Player Name    0.0
# dtype: float64

# %%
df1.head(20)
# Out:
#            Team1         Team2                                  Toss  \
# 0   South Africa   West Indies  South Africa, elected to field first
# 1          India   West Indies           India, elected to bat first
# 2   South Africa     Sri Lanka     Sri Lanka, elected to field first
# 3       Pakistan   West Indies     West Indies, elected to bat first
# 4      Australia         India     Australia, elected to field first
# 5    New Zealand     Sri Lanka     Sri Lanka, elected to field first
# 6        England  South Africa         England, elected to bat first
# 7    New Zealand      Zimbabwe        Zimbabwe, elected to bat first
# 8          India   New Zealand   New Zealand, elected to field first
# 9          India  South Africa           India, elected to bat first
# 10   New Zealand      Pakistan        Pakistan, elected to bat first
# 11       England  South Africa         England, elected to bat first
# 12   New Zealand      Zimbabwe      Zimbabwe, elected to field first
# ...

# %%
df1.head(90)
# Out:
#            Team1         Team2                                  Toss  \
# 0   South Africa   West Indies  South Africa, elected to field first
# 1          India   West Indies           India, elected to bat first
# 2   South Africa     Sri Lanka     Sri Lanka, elected to field first
# 3       Pakistan   West Indies     West Indies, elected to bat first
# 4      Australia         India     Australia, elected to field first
# ..           ...           ...                                   ...
# 85       England         India       England, elected to field first
# 86         India     Sri Lanka         India, elected to field first
# 87       England  South Africa       England, elected to field first
# 88     Australia     Sri Lanka     Australia, elected to field first
# 89       England   New Zealand   New Zealand, elected to field first
#
#    Match days        Winner Player of the Match     Margin      Ground  \
# ...

# %%
df1["Player of the Match"]=df1["Player of the Match"].fillna("unknown")

# %%
df1
# Out:
#             Team1         Team2                                  Toss  \
# 0    South Africa   West Indies  South Africa, elected to field first
# 1           India   West Indies           India, elected to bat first
# 2    South Africa     Sri Lanka     Sri Lanka, elected to field first
# 3        Pakistan   West Indies     West Indies, elected to bat first
# 4       Australia         India     Australia, elected to field first
# ..            ...           ...                                   ...
# 123         India      Pakistan      Pakistan, elected to field first
# 124     Australia       England     Australia, elected to field first
# 125   Afghanistan  South Africa    South Africa, elected to bat first
# 126    Bangladesh         India      Bangladesh, elected to bat first
# 127      Pakistan   New Zealand      Pakistan, elected to field first
#
#     Match days        Winner Player of the Match     Margin        Ground  \
# ...

# %%
df1.head(50)
# Out:
#            Team1         Team2  \
# 0   South Africa   West Indies
# 1          India   West Indies
# 2   South Africa     Sri Lanka
# 3       Pakistan   West Indies
# 4      Australia         India
# 5    New Zealand     Sri Lanka
# 6        England  South Africa
# 7    New Zealand      Zimbabwe
# 8          India   New Zealand
# 9          India  South Africa
# 10   New Zealand      Pakistan
# 11       England  South Africa
# 12   New Zealand      Zimbabwe
# 13      Pakistan     Sri Lanka
# 14     Australia         India
# 15    Bangladesh       England
# 16     Sri Lanka   West Indies
# 17         Kenya         India
# 18     Sri Lanka         India
# 19     Sri Lanka         India
# 20     Sri Lanka     Australia
# 21         India  South Africa
# 22    Bangladesh   New Zealand
# 23       England         India
# 24   Netherlands      Pakistan
# 25         Kenya  South Africa
# 26     Australia    Bangladesh
# 27       England      Zimbabwe
# 28         Kenya   West Indies
# ...

# %%
df1.isnull().sum()
# Out:
# Team1                           0
# Team2                           0
# Toss                            0
# Match days                      0
# Winner                          0
# Player of the Match             0
# Margin                          0
# Ground                          0
# Match Date                      0
# ODI Int Match                   0
# Team1 Avg Batting Ranking       0
# Team2 Avg Batting Ranking       0
# Team1 Avg Bowling Ranking       0
# Team2 Avg Bowling Ranking       0
# Team1 Total CTs participated    0
# Team1 Total CTs won             0
# Team2 Total CTs participated    0
# Team2 Total CTs won             0
# Team1 W/L ratio over Team2      0
# dtype: int64

# %%
df1.to_csv("cleaneddata.csv",index=False)

# %%
df2.to_csv("cleaneddata2.csv",
